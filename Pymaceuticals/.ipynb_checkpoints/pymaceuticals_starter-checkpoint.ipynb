# %% [markdown]
# ## Observations and Insights
# 1. Based on their low tumor volumes Capomulin and Ramicane appear to be the two most effective drug regimens. We do not know how if all tumors started off the same size though, so further info is needed to draw stronger conclusions. Capomulin and Ramicane were also the most tested based on total time points.
#
# 2. Average weight and Tumor Volume had a strong correlation. Weight should be taken into account when making final conclusions about the effictiveness of these regimens.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
from functools import reduce
import numpy as np
from scipy.stats import linregress
import warnings
warnings.filterwarnings("ignore")

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
allData = mouse_metadata.merge(study_results, on='Mouse ID', how = 'outer')
# Display the data table for preview

allData.tail()
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 1888           63.145652                 2
# 1889           65.841013                 3
# 1890           69.176246                 4
# 1891           70.314904                 4
# 1892           73.867845                 4

# %%
# to get a quick statistical summary of data
allData.describe()
# Out:
#         Age_months   Weight (g)    Timepoint  Tumor Volume (mm3)  \
# count  1893.000000  1893.000000  1893.000000         1893.000000
# mean     12.814580    25.662441    19.572108           50.448381
# std       7.189592     3.921622    14.079460            8.894722
# min       1.000000    15.000000     0.000000           22.050126
# 25%       7.000000    25.000000     5.000000           45.000000
# 50%      13.000000    27.000000    20.000000           48.951474
# 75%      20.000000    29.000000    30.000000           56.292200
# max      24.000000    30.000000    45.000000           78.567014
#
#        Metastatic Sites
# count       1893.000000
# mean           1.021659
# std            1.137974
# min            0.000000
# 25%            0.000000
# 50%            1.000000
# 75%            2.000000
# max            4.000000

# %%
# to get a quick overview of the data, get column names, and datatypes
allData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1893 entries, 0 to 1892
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Mouse ID            1893 non-null   object
#  1   Drug Regimen        1893 non-null   object
#  2   Sex                 1893 non-null   object
#  3   Age_months          1893 non-null   int64
#  4   Weight (g)          1893 non-null   int64
#  5   Timepoint           1893 non-null   int64
#  6   Tumor Volume (mm3)  1893 non-null   float64
#  7   Metastatic Sites    1893 non-null   int64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 133.1+ KB

# %%
# Checking the number of mice.
len(allData['Mouse ID'].unique())
# Out:
# 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 

# create a count column and set the value in all rows equal to 1
allData['Count'] = 1

# create a count dataframe and group the count column by 1 
countDF = allData.groupby('Mouse ID').sum()

# show max values
# countDF = allData.groupby('Mouse ID').sum().max()

# grab row where count equals max value
countDF.loc[countDF['Count']==13]
# Out:
#           Age_months  Weight (g)  Timepoint  Tumor Volume (mm3)  \
# Mouse ID
# g989             273         338        190          680.433258
#
#           Metastatic Sites  Count
# Mouse ID
# g989                     7     13

# %%
# Optional: Get all the data for the duplicate mouse ID. 

allData.loc[allData['Mouse ID'] == "g989"]
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 908     g989     Propriva  Female          21          26          0
# 909     g989     Propriva  Female          21          26          0
# 910     g989     Propriva  Female          21          26          5
# 911     g989     Propriva  Female          21          26          5
# 912     g989     Propriva  Female          21          26         10
# 913     g989     Propriva  Female          21          26         10
# 914     g989     Propriva  Female          21          26         15
# 915     g989     Propriva  Female          21          26         15
# 916     g989     Propriva  Female          21          26         20
# 917     g989     Propriva  Female          21          26         20
# 918     g989     Propriva  Female          21          26         25
# 919     g989     Propriva  Female          21          26         30
# 920     g989     Propriva  Female          21          26         35
#
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.

# drop added count column
allData.drop(columns='Count',inplace=True)

# create a new data frame where none of the Mouse ID's equal g989
cleanData = allData[allData['Mouse ID'] != 'g989']

# display new data frame
cleanData.head()
# Out:
#   Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0     k403     Ramicane  Male          21          16          0
# 1     k403     Ramicane  Male          21          16          5
# 2     k403     Ramicane  Male          21          16         10
# 3     k403     Ramicane  Male          21          16         15
# 4     k403     Ramicane  Male          21          16         20
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           45.000000                 0
# 1           38.825898                 0
# 2           35.014271                 1
# 3           34.223992                 1
# 4           32.997729                 1

# %%
# Checking the number of mice in the clean DataFrame.
len(cleanData['Mouse ID'].unique())
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary dataframe.

# Generate summary statistics
subDF = cleanData[['Drug Regimen','Tumor Volume (mm3)']]

mean = subDF.groupby('Drug Regimen').mean()
mean.columns=['Mean']
median = subDF.groupby('Drug Regimen').median()
median.columns=['Median']
variance = subDF.groupby('Drug Regimen').var()
variance.columns=['Variance']
stdDEV= subDF.groupby('Drug Regimen').std()
stdDEV.columns=['Std.DEV']
sem = subDF.groupby('Drug Regimen').sem()
sem.columns=['SEM']

# put dfs into list
dfs = [mean, median, variance, stdDEV, sem]

# join dfs together
finalDf = reduce(lambda  left,right: pd.merge(left,right,on=['Drug Regimen'],
                                            how='outer'), dfs)
finalDf
# Out:
#                    Mean     Median   Variance   Std.DEV       SEM
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355  6.966589  0.516398

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Using the aggregation method, produce the same summary statistics in a single line
summary= subDF.groupby('Drug Regimen').agg({'Tumor Volume (mm3)': 
                                            [("Mean","mean"), ("Median", "median"), 
                                            ("Variance","var"), ('Std. Dev','std'), 
                                            ('SEM', 'sem')]}) 
summary
# Out:
#              Tumor Volume (mm3)
#                            Mean     Median   Variance  Std. Dev       SEM
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using Pandas.

subDF = cleanData[['Drug Regimen','Timepoint']]
sum1 = subDF.groupby('Drug Regimen').count()
sum1
# Out:
#               Timepoint
# Drug Regimen
# Capomulin           230
# Ceftamin            178
# Infubinol           178
# Ketapril            188
# Naftisol            186
# Placebo             181
# Propriva            148
# Ramicane            228
# Stelasyn            181
# Zoniferol           182

# %%
sum1.plot.bar()
# Out:
# <AxesSubplot:xlabel='Drug Regimen'>

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using pyplot.

num = [230, 178, 178, 188, 186, 181, 161, 228, 181, 182]

#Set the xAxis to be the total number of timepoints
xAxis = np.arange(len(sum1))

plt.bar(xAxis, num, color='g', align='center')

tick_locations = [value for value in xAxis]
plt.xticks(tick_locations, ['Capomulin', 'Ceftamin', 'Infubinol', 'Ketapril', 'Naftisol', 'Placebo', 'Propriva', 'Ramicane', 'Stelasyn', 'Zoniferol'],  rotation='vertical')
plt.xlabel("Drug Regimen")
plt.ylabel("Timepoints")
plt.show()

# %%
#Group by "Mouse ID" and "Sex" to find the unique number of male vs female
gender = cleanData.groupby(["Mouse ID","Sex"])
gender

mouseGender = pd.DataFrame(gender.size())

#Create the dataframe with total count of Female and Male mice
mouseGender = pd.DataFrame(mouseGender.groupby(["Sex"]).count())
mouseGender.columns = ["Total Count"]

#create and format the percentage of female vs male
mouseGender["Percentage of Sex"] = (100*(mouseGender["Total Count"]/mouseGender["Total Count"].sum()))

#format the "Percentage of Sex" column
mouseGender["Percentage of Sex"] = mouseGender["Percentage of Sex"]

#gender_df
mouseGender
# Out:
#         Total Count  Percentage of Sex
# Sex
# Female          123          49.596774
# Male            125          50.403226

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas
explode = (0.1, 0)
mouseGender.plot.pie(y='Total Count',figsize=(5,5), explode = explode, shadow = True, autopct="%1.1f%%")
# Out:
# <AxesSubplot:ylabel='Total Count'>

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot

# Create Labels for the sections of the pie
labels = ["Female","Male"]

#List the values of each section of the pie chart
sizes = [49.596774,50.403226]

#Set colors for each section of the pie
colors = ['blue', 'red']

#Determoine which section of the circle to detach
explode = (0.1, 0)

#Create the pie chart based upon the values 
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct="%1.1f%%", shadow=True, startangle=91)

#Set equal axis
plt.axis("equal")
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse
lastTimePointDF = pd.DataFrame(cleanData.groupby('Mouse ID')['Timepoint'].max().sort_values()).rename(columns={'Timepoint': 'max_timepoint'})
lastTimePointDF

# Merge this group df with the original dataframe to get the tumor volume at the last timepoint
mergedDF = pd.merge(cleanData, lastTimePointDF, on='Mouse ID')
mergedDF.head()
# Out:
#   Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0     k403     Ramicane  Male          21          16          0
# 1     k403     Ramicane  Male          21          16          5
# 2     k403     Ramicane  Male          21          16         10
# 3     k403     Ramicane  Male          21          16         15
# 4     k403     Ramicane  Male          21          16         20
#
#    Tumor Volume (mm3)  Metastatic Sites  max_timepoint
# 0           45.000000                 0             45
# 1           38.825898                 0             45
# 2           35.014271                 1             45
# 3           34.223992                 1             45
# 4           32.997729                 1             45

# %%
# Put treatments into a list for for loop (and later for plot labels)
regimen = ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin']



# Create empty list to fill with tumor vol data (for plotting)
regimenValues = []

# Calculate the IQR and quantitatively determine if there are any potential outliers. 

    
for regimen in regimen:
    
    temp = mergedDF.loc[mergedDF['Drug Regimen'] == regimen]

    # add subset
    finalDF = temp.loc[temp['Timepoint'] == temp['max_timepoint']]
    
    # Locate the rows which contain mice on each drug and get the tumor volumes
    values = finalDF['Tumor Volume (mm3)']
    regimenValues.append(values)
    
    # Calculate and print the interquartile range (IQR) for each regimen
    quartiles = values.quantile([.25,.5,.75])
    lowerq = quartiles[0.25]
    upperq = quartiles[0.75]
    iqr = upperq-lowerq
    print(f'IQR for {regimen}: {iqr}')
    
    # Find upper and lower bounds to help identify outliers for each regimen
    lower_bound = lowerq - (1.5*iqr)
    upper_bound = upperq + (1.5*iqr)
    print(f'Lower Bound for {regimen}: {lower_bound}')
    print(f'Upper Bound for {regimen}: {upper_bound}')
    
    # Determine outliers using upper and lower bounds
    outliers_count = (values.loc[(finalDF['Tumor Volume (mm3)'] >= upper_bound) | 
                                        (finalDF['Tumor Volume (mm3)'] <= lower_bound)]).count()
    print(f'Number of {regimen} outliers: {outliers_count}')
# Out:
# IQR for Capomulin: 7.781863460000004
# Lower Bound for Capomulin: 20.70456164999999
# Upper Bound for Capomulin: 51.83201549
# Number of Capomulin outliers: 0
# IQR for Ramicane: 9.098536719999998
# Lower Bound for Ramicane: 17.912664470000003
# Upper Bound for Ramicane: 54.30681135
# Number of Ramicane outliers: 0
# IQR for Infubinol: 11.477135160000003
# Lower Bound for Infubinol: 36.83290494999999
# Upper Bound for Infubinol: 82.74144559000001
# Number of Infubinol outliers: 1
# IQR for Ceftamin: 15.577752179999997
# Lower Bound for Ceftamin: 25.355449580000002
# Upper Bound for Ceftamin: 87.66645829999999
# Number of Ceftamin outliers: 0

# %%
# # Generate a box plot of the final tumor volume of each mouse across four regimens of interest
flierprops = dict(marker='o', markerfacecolor='b', markersize=8, markeredgecolor='black')

# # Plot boxplot
plt.boxplot(regimenValues, flierprops=flierprops)

# Add title and labels to boxplot
plt.title('Final Tumor Volume by Drug')
plt.ylabel('Final Tumor Volume (mm3)')
plt.xticks([1, 2, 3, 4], ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin'])

plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen

# Isolate cases that only use the Capomulin regimen
capomulinDF = mergedDF.loc[mergedDF['Drug Regimen'] == 'Capomulin']

# Find average tumor volume for each mouse

avTumVol = pd.DataFrame(capomulinDF.groupby('Mouse ID')['Tumor Volume (mm3)'].mean().sort_values()).rename(columns={'Tumor Volume (mm3)': 'Avg. Tumor Vol'})

# Create new dataframe by merge average tumor volume onto data_df and drop duplicates
avTumVol = pd.merge(capomulinDF, avTumVol, on='Mouse ID')
finalDF = avTumVol[['Weight (g)', 'Avg. Tumor Vol']].drop_duplicates()
# finalDF.info()

x = finalDF['Weight (g)']
y = finalDF['Avg. Tumor Vol']

# Create a scatter plot based on new dataframe above with circle markers and listed colors
plt.scatter(x, y)

# Add labels and title to plot
plt.xlabel("Weight (g)")
plt.ylabel("Average Tumor Volume (mm3)")
plt.title('Average Tumor Volume by Weight')
# Display plot
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen

correlation = st.pearsonr(finalDF['Weight (g)'],finalDF['Avg. Tumor Vol'])


# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen

xValues = finalDF['Weight (g)']
yValues = finalDF['Avg. Tumor Vol']
(slope, intercept, rvalue, pvalue, stderr) = linregress(xValues, yValues)
regress_values = xValues * slope + intercept
plt.scatter(xValues,yValues)
plt.plot(xValues,regress_values,"g-")
plt.annotate(line_eq,(23,43),fontsize=15,color="black")
plt.title("Weight (g) vs. Avg. Tumor Volume")
plt.xlabel("Weight (g)")
plt.ylabel("Tumor Volume (mm3)")
plt.show()
